# %% [markdown]
# # Limpeza de Dados

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
dados_exp=pd.read_csv('./Base de Dados/IBGE_SIDRA_ExpVidaSexo_2010.csv')

# %%
dados_exp['REGIAO']='OK'

# %%
norte=['Amazonas','Acre','Rondônia','Roraima','Pará','Amapá','Tocantins']
nordeste=['Maranhão','Ceará','Piauí','Rio Grande do Norte','Paraíba','Pernambuco','Alagoas','Sergipe','Bahia']
centro_oeste=['Mato Grosso','Mato Grosso do Sul','Goiás','Distrito Federal']
sudeste=['Minas Gerais','São Paulo','Rio de Janeiro','Espírito Santo']
sul=['Paraná','Santa Catarina','Rio Grande do Sul']
for i in range(1,len(dados_exp)):
    if dados_exp.iloc[i,6] in norte:
        dados_exp.iloc[i,13]='Norte'
    elif dados_exp.iloc[i,6] in nordeste:
        dados_exp.iloc[i,13]='Nordeste'
    elif dados_exp.iloc[i,6] in centro_oeste:
        dados_exp.iloc[i,13]='Centro-Oeste'
    elif dados_exp.iloc[i,6] in sudeste:
        dados_exp.iloc[i,13]='Sudeste'
    elif dados_exp.iloc[i,6] in sul:
        dados_exp.iloc[i,13]='Sul'

# %%
dados_exp
# Out:
#                             NC                    NN  \
# 0   Nível Territorial (Código)     Nível Territorial
# 1                            3  Unidade da Federação
# 2                            3  Unidade da Federação
# 3                            3  Unidade da Federação
# 4                            3  Unidade da Federação
# 5                            3  Unidade da Federação
# 6                            3  Unidade da Federação
# 7                            3  Unidade da Federação
# 8                            3  Unidade da Federação
# 9                            3  Unidade da Federação
# 10                           3  Unidade da Federação
# 11                           3  Unidade da Federação
# 12                           3  Unidade da Federação
# 13                           3  Unidade da Federação
# 14                           3  Unidade da Federação
# 15                           3  Unidade da Federação
# 16                           3  Unidade da Federação
# 17                           3  Unidade da Federação
# 18                           3  Unidade da Federação
# 19                           3  Unidade da Federação
# 20                           3  Unidade da Federação
# 21                           3  Unidade da Federação
# 22                           3  Unidade da Federação
# 23                           3  Unidade da Federação
# 24                           3  Unidade da Federação
# 25                           3  Unidade da Federação
# 26                           3  Unidade da Federação
# 27                           3  Unidade da Federação
# 28                           3  Unidade da Federação
# 29                           3  Unidade da Federação
# 30                           3  Unidade da Federação
# 31                           3  Unidade da Federação
# 32                           3  Unidade da Federação
# 33                           3  Unidade da Federação
# 34                           3  Unidade da Federação
# 35                           3  Unidade da Federação
# 36                           3  Unidade da Federação
# 37                           3  Unidade da Federação
# 38                           3  Unidade da Federação
# 39                           3  Unidade da Federação
# 40                           3  Unidade da Federação
# 41                           3  Unidade da Federação
# 42                           3  Unidade da Federação
# 43                           3  Unidade da Federação
# 44                           3  Unidade da Federação
# 45                           3  Unidade da Federação
# 46                           3  Unidade da Federação
# 47                           3  Unidade da Federação
# 48                           3  Unidade da Federação
# 49                           3  Unidade da Federação
# 50                           3  Unidade da Federação
# 51                           3  Unidade da Federação
# 52                           3  Unidade da Federação
# 72  Centro-Oeste
# 73  Centro-Oeste
# 74  Centro-Oeste
# 75  Centro-Oeste
# 76  Centro-Oeste
# 77  Centro-Oeste
# 78  Centro-Oeste
# 79  Centro-Oeste
# 80  Centro-Oeste
# 81  Centro-Oeste

# %%
expec_norte=[]
expec_nordeste=[]
expec_centro=[]
expec_sudeste=[]
expec_sul=[]
for i in range(1,len(dados_exp)):
    if dados_exp.iloc[i,10]=='Total' and dados_exp.iloc[i,13]=='Norte':
        quero=dados_exp.iloc[i,4]
        expec_norte.append(float(quero))
    elif dados_exp.iloc[i,10]=='Total' and dados_exp.iloc[i,13]=='Nordeste':
        quero=dados_exp.iloc[i,4]
        expec_nordeste.append(float(quero))
    elif dados_exp.iloc[i,10]=='Total' and dados_exp.iloc[i,13]=='Centro-Oeste':
        quero=dados_exp.iloc[i,4]
        expec_centro.append(float(quero))
    elif dados_exp.iloc[i,10]=='Total' and dados_exp.iloc[i,13]=='Sudeste':
        quero=dados_exp.iloc[i,4]
        expec_sudeste.append(float(quero))
    elif dados_exp.iloc[i,10]=='Total' and dados_exp.iloc[i,13]=='Sul':
        quero=dados_exp.iloc[i,4]
        expec_sul.append(float(quero))

# %%
med_norte=np.mean(expec_norte)
med_nordeste=np.mean(expec_nordeste)
med_centro=np.mean(expec_centro)
med_nordeste=np.mean(expec_nordeste)
med_sul=np.mean(expec_sul)

# %%
print(f'Expectativa de vida média região Norte: {med_norte:.2f}')
print(f'Expectativa de vida média região Nordeste: {med_nordeste:.2f}')
print(f'Expectativa de vida média região Centro-Oeste: {med_centro:.2f}')
print(f'Expectativa de vida média região Sudeste: {med_nordeste:.2f}')
print(f'Expectativa de vida média região Sul: {med_sul:.2f}')
# Out:
# Expectativa de vida média região Norte: 70.90
# Expectativa de vida média região Nordeste: 71.06
# Expectativa de vida média região Centro-Oeste: 73.95
# Expectativa de vida média região Sudeste: 71.06
# Expectativa de vida média região Sul: 76.03

# %%
fig, ax = plt.subplots(figsize =(10, 6))
medias=[76.03,73.95,71.06,71.06,70.09]
labels=['Sul','Centro-Oeste','Nordeste','Sudeste','Norte']
ax.barh(labels, medias)
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
ax.invert_yaxis()
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='tab:gray')
ax.set_title('Expectativa de Vida por Região - 2010',
             loc ='center')
plt.xlabel('Idade (Anos)')
plt.show()

# %% [markdown]
# # Região Sul

# %%
dados_exp[dados_exp['REGIAO']=='Sul']
# Out:
#    NC                    NN    MC    MN     V D1C                D1N   D2C  \
# 61  3  Unidade da Federação  1622  Anos  75.2  41             Paraná  2503
# 62  3  Unidade da Federação  1622  Anos  71.9  41             Paraná  2503
# 63  3  Unidade da Federação  1622  Anos  78.6  41             Paraná  2503
# 64  3  Unidade da Federação  1622  Anos  76.9  42     Santa Catarina  2503
# 65  3  Unidade da Federação  1622  Anos  73.6  42     Santa Catarina  2503
# 66  3  Unidade da Federação  1622  Anos  80.4  42     Santa Catarina  2503
# 67  3  Unidade da Federação  1622  Anos  76.0  43  Rio Grande do Sul  2503
# 68  3  Unidade da Federação  1622  Anos  72.4  43  Rio Grande do Sul  2503
# 69  3  Unidade da Federação  1622  Anos  79.5  43  Rio Grande do Sul  2503
#
#                             D2N   D3C       D3N   D4C   D4N REGIAO
# 61  Esperança de vida ao nascer  6794     Total  2010  2010    Sul
# 62  Esperança de vida ao nascer     4    Homens  2010  2010    Sul
# 63  Esperança de vida ao nascer     5  Mulheres  2010  2010    Sul
# 64  Esperança de vida ao nascer  6794     Total  2010  2010    Sul
# 65  Esperança de vida ao nascer     4    Homens  2010  2010    Sul
# 66  Esperança de vida ao nascer     5  Mulheres  2010  2010    Sul
# 67  Esperança de vida ao nascer  6794     Total  2010  2010    Sul
# 68  Esperança de vida ao nascer     4    Homens  2010  2010    Sul
# 69  Esperança de vida ao nascer     5  Mulheres  2010  2010    Sul

# %%
estados_sul=['Santa Catarina','Rio Grande do Sul','Paraná']
expec_h=[73.6,72.4,71.9]
expec_m=[80.4,79.5,78.6]

# %% [markdown]
# ## Homens

# %%
fig, ax = plt.subplots(figsize =(10, 6))
ax.barh(estados_sul, expec_h, color='tab:cyan')
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
ax.invert_yaxis()
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='tab:gray')
ax.set_title('Expectativa de Vida Região Sul (Homens) - 2010',
             loc ='center')
plt.xlabel('Idade (Anos)')
plt.show()

# %% [markdown]
# ## Mulheres

# %%
fig, ax = plt.subplots(figsize =(10, 6))
ax.barh(estados_sul, expec_m, color='darkorchid')
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
ax.invert_yaxis()
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='tab:gray')
ax.set_title('Expectativa de Vida Região Sul (Mulheres) - 2010',
             loc ='center')
plt.xlabel('Idade (Anos)')
plt.show()

# %% [markdown]
# # Região Norte

# %%
dados_norte=dados_exp[dados_exp['REGIAO']=='Norte']
dados_norte
# Out:
#    NC                    NN    MC    MN     V D1C        D1N   D2C  \
# 1   3  Unidade da Federação  1622  Anos  70.1  11   Rondônia  2503
# 2   3  Unidade da Federação  1622  Anos  67.0  11   Rondônia  2503
# 3   3  Unidade da Federação  1622  Anos  73.8  11   Rondônia  2503
# 4   3  Unidade da Federação  1622  Anos  71.7  12       Acre  2503
# 5   3  Unidade da Federação  1622  Anos  68.5  12       Acre  2503
# 6   3  Unidade da Federação  1622  Anos  75.4  12       Acre  2503
# 7   3  Unidade da Federação  1622  Anos  70.4  13   Amazonas  2503
# 8   3  Unidade da Federação  1622  Anos  67.3  13   Amazonas  2503
# 9   3  Unidade da Federação  1622  Anos  73.8  13   Amazonas  2503
# 10  3  Unidade da Federação  1622  Anos  69.5  14    Roraima  2503
# 11  3  Unidade da Federação  1622  Anos  66.9  14    Roraima  2503
# 12  3  Unidade da Federação  1622  Anos  72.5  14    Roraima  2503
# 13  3  Unidade da Federação  1622  Anos  70.9  15       Pará  2503
# 14  3  Unidade da Federação  1622  Anos  67.5  15       Pará  2503
# 15  3  Unidade da Federação  1622  Anos  74.7  15       Pará  2503
# 16  3  Unidade da Federação  1622  Anos  72.1  16      Amapá  2503
# 17  3  Unidade da Federação  1622  Anos  69.2  16      Amapá  2503
# 18  3  Unidade da Federação  1622  Anos  75.4  16      Amapá  2503
# 19  3  Unidade da Federação  1622  Anos  71.6  17  Tocantins  2503
# 20  3  Unidade da Federação  1622  Anos  68.7  17  Tocantins  2503
# 21  3  Unidade da Federação  1622  Anos  74.9  17  Tocantins  2503
#
#                             D2N   D3C       D3N   D4C   D4N REGIAO
# 1   Esperança de vida ao nascer  6794     Total  2010  2010  Norte
# 2   Esperança de vida ao nascer     4    Homens  2010  2010  Norte
# 3   Esperança de vida ao nascer     5  Mulheres  2010  2010  Norte
# 4   Esperança de vida ao nascer  6794     Total  2010  2010  Norte
# 5   Esperança de vida ao nascer     4    Homens  2010  2010  Norte
# 6   Esperança de vida ao nascer     5  Mulheres  2010  2010  Norte
# 7   Esperança de vida ao nascer  6794     Total  2010  2010  Norte
# 8   Esperança de vida ao nascer     4    Homens  2010  2010  Norte
# 9   Esperança de vida ao nascer     5  Mulheres  2010  2010  Norte
# 10  Esperança de vida ao nascer  6794     Total  2010  2010  Norte
# 11  Esperança de vida ao nascer     4    Homens  2010  2010  Norte
# 12  Esperança de vida ao nascer     5  Mulheres  2010  2010  Norte
# 13  Esperança de vida ao nascer  6794     Total  2010  2010  Norte
# 14  Esperança de vida ao nascer     4    Homens  2010  2010  Norte
# 15  Esperança de vida ao nascer     5  Mulheres  2010  2010  Norte
# 16  Esperança de vida ao nascer  6794     Total  2010  2010  Norte
# 17  Esperança de vida ao nascer     4    Homens  2010  2010  Norte
# 18  Esperança de vida ao nascer     5  Mulheres  2010  2010  Norte
# 19  Esperança de vida ao nascer  6794     Total  2010  2010  Norte
# 20  Esperança de vida ao nascer     4    Homens  2010  2010  Norte
# 21  Esperança de vida ao nascer     5  Mulheres  2010  2010  Norte

# %%
dic_h={}
dic_m={}
for i in range(0,len(dados_norte)):
    if dados_norte.iloc[i,10]=='Homens':
        dic_h[dados_norte.iloc[i,6]]=dados_norte.iloc[i,4]
    elif dados_norte.iloc[i,10]=='Mulheres':
        dic_m[dados_norte.iloc[i,6]]=dados_norte.iloc[i,4]

# %%
# Homens
for j in sorted(dic_h, key = dic_h.get, reverse=True):
    print(j, dic_h[j])
# Out:
# Amapá 69.2
# Tocantins 68.7
# Acre 68.5
# Pará 67.5
# Amazonas 67.3
# Rondônia 67.0
# Roraima 66.9

# %%
# Mulheres
for j in sorted(dic_m, key = dic_m.get, reverse=True):
    print(j, dic_m[j])
# Out:
# Acre 75.4
# Amapá 75.4
# Tocantins 74.9
# Pará 74.7
# Rondônia 73.8
# Amazonas 73.8
# Roraima 72.5

# %%
estados_norte_h=['Amapá','Tocantins','Acre','Pará','Amazonas','Rondônia','Roraima']
expec_h=[69.2,68.7,68.5,67.5,67.3,67,66.9]

# %%
estados_norte_m=['Acre','Amapá','Tocantins','Pará','Rondônia','Amazonas','Roraima']
expec_m=[75.4,75.4,74.9,74.7,73.8,73.8,72.5]

# %% [markdown]
# ## Homens

# %%
fig, ax = plt.subplots(figsize =(10, 6))
ax.barh(estados_norte_h, expec_h, color='tab:cyan')
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
ax.invert_yaxis()
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='tab:gray')
ax.set_title('Expectativa de Vida Região Norte (Homens) - 2010',
             loc ='center')
plt.xlabel('Idade (Anos)')
plt.show()

# %% [markdown]
# ## Mulheres

# %%
fig, ax = plt.subplots(figsize =(10, 6))
ax.barh(estados_norte_m, expec_m, color='darkorchid')
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.6)
ax.invert_yaxis()
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='tab:gray')
ax.set_title('Expectativa de Vida Região Norte (Mulheres) - 2010',
             loc ='center')
plt.xlabel('Idade (Anos)')
plt.show()
